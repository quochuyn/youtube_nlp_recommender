# %%
# data science
import numpy as np
import pandas as pd

import get_youtube_data

# %%
# Step 1. Get the youtube API key. For now we can just grab 1, but in the future
#         we will need to obtain a list of API keys due to the high quota cost of
#         performing a youtube search.
YOUTUBE_API_KEY = get_youtube_data.get_youtube_api_key()
# YOUTUBE_API_KEYS = get_youtube_data.get_youtube_api_key_list()

# %%
# Step 2. Build the youtube client to make API calls.
youtube = get_youtube_data.make_client(YOUTUBE_API_KEY)

# %%
# Step 3. Perform a youtube search with a user-specified query.
youtube_df = get_youtube_data.search_youtube(
    youtube,
    query='bossa nova',
    max_vids=50,        # youtube accepts 50 as the max value
    order='relevance'   # default is relevance
)

# %%
youtube_df.sample(5)
# Out:
#        video_id          published_at                channel_id  \
# 27  DWqOOLWX2t8  2023-07-06T20:13:05Z  UCaCE5pzy49M8nQ59plgmFOA
# 38  N7yiuZ-TpQw  2020-11-12T13:00:03Z  UCto8k_Rrg_5WW71pMX3BSuw
# 1   DgC6yuoX8l8  2023-07-06T15:15:28Z  UCJhjE7wbdYAae1G25m0tHAA
# 40  _qoh9g29ib8  2023-04-30T18:46:51Z  UCJuMbdKSMThk2RpALASyXVQ
# 47  laCAYYO16jE  2023-05-05T04:00:22Z  UC9pi-E5v-V7O5WVtlaFFIBQ
#
#                                                 title  \
# 27  Friday Morning Jazz - Jazz &amp; Bossa Nova Mu...
# 38  Best Bossa Nova Songs Of All Time | Jazz Bossa...
# 1   FRIDAY MORNING JAZZ: Jazz &amp; Bossa Nova - C...
# 40  Seaside Cafe Ambience with Summer Jazz, Bossa ...
# 47  Best Bossa Nova 2023 - Greatest Hits Bossa Nov...
#
#                                           description  \
# 27  The best of happy morning jazz and positive bo...
# 38  Best Bossa Nova Songs Of All Time | Jazz Bossa...
# 1   Listen Everywhere → Good Morning FRIDAY: https...
# 40  Enjoy this seaside cafe ambience with summer j...
# 47  Best Bossa Nova 2023 - Greatest Hits Bossa Nov...
#
#                                 thumbnail_default_url  \
# 27  https://i.ytimg.com/vi/DWqOOLWX2t8/default_liv...
# 38     https://i.ytimg.com/vi/N7yiuZ-TpQw/default.jpg
# 1   https://i.ytimg.com/vi/DgC6yuoX8l8/default_liv...
# 40     https://i.ytimg.com/vi/_qoh9g29ib8/default.jpg
# 47     https://i.ytimg.com/vi/laCAYYO16jE/default.jpg
#
#                                  thumbnail_medium_url  \
# 27  https://i.ytimg.com/vi/DWqOOLWX2t8/mqdefault_l...
# 38   https://i.ytimg.com/vi/N7yiuZ-TpQw/mqdefault.jpg
# 1   https://i.ytimg.com/vi/DgC6yuoX8l8/mqdefault_l...
# 40   https://i.ytimg.com/vi/_qoh9g29ib8/mqdefault.jpg
# 47   https://i.ytimg.com/vi/laCAYYO16jE/mqdefault.jpg
#
#                                    thumbnail_high_url  \
# 27  https://i.ytimg.com/vi/DWqOOLWX2t8/hqdefault_l...
# 38   https://i.ytimg.com/vi/N7yiuZ-TpQw/hqdefault.jpg
# 1   https://i.ytimg.com/vi/DgC6yuoX8l8/hqdefault_l...
# 40   https://i.ytimg.com/vi/_qoh9g29ib8/hqdefault.jpg
# 47   https://i.ytimg.com/vi/laCAYYO16jE/hqdefault.jpg
#
#                channel_title  \
# 27          Relax Cafe Music
# 38              Diva Channel
# 1     Cafe Music BGM channel
# 40          Calmed By Nature
# 47  Phoenix Luxury Official
#
#                                                  tags  video_duration  \
# 27                                                 []             0.0
# 38  [bossa nova, bossa nova songs, bossa nova best...          4871.0
# 1   [Friday, morning, jazz, bossa, bossa nova, cel...             0.0
# 40  [seaside cafe, beach cafe ambience, seaside ca...         28981.0
# 47  [bossa nova, bossa nova cover, bossa nova cove...          4364.0
#
#    video_caption video_view_count video_like_count video_comment_count
# 27         false            13591              153                   0
# 38         false          5195385            42237                 605
# 1          false            64202              323                   0
# 40         false           144242             3259                 392
# 47         false           186735             1444                  22
